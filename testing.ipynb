# %% [markdown]
# <a href="https://colab.research.google.com/github/J1gsy/machine_learning/blob/main/testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import transactionencoder

# %%
data_raw = [
    ['pen', 'book', 'pencil', 'eraser', 'board marker', 'sharpener'],
    ['color pencil', 'drawing book', 'eraser', 'pencil', 'sharpener',],
    ['book', 'pen', 'pencil', 'eraser'],
    ['eraser', 'pencil', 'color pencil', 'sharpener',],
    ['pen', 'book', 'correction fluid', 'board marker', 'pencil']
]

# %%
# fix data formating before convert into dataframe
te = transactionencoder.TransactionEncoder()
te_ary = te.fit(data_raw).transform(data_raw)

# %%
# convert raw data into data frame
dataset = pd.DataFrame(te_ary, columns=te.columns_)
dataset.head()
# Out:
#    board marker   book  color pencil  ...    pen  pencil  sharpener
# 0          True   True         False  ...   True    True       True
# 1         False  False          True  ...  False    True       True
# 2         False   True         False  ...   True    True      False
# 3         False  False          True  ...  False    True       True
# 4          True   True         False  ...   True    True      False
#
# [5 rows x 9 columns]

# %%
# search the transaction with support >= 0.6
frequent_itemset = apriori(dataset, min_support=0.6, use_colnames=True)
frequent_itemset
# Out:
#     support                     itemsets
# 0       0.6                       (book)
# 1       0.8                     (eraser)
# 2       0.6                        (pen)
# 3       1.0                     (pencil)
# 4       0.6                  (sharpener)
# 5       0.6                  (book, pen)
# 6       0.6               (book, pencil)
# 7       0.8             (pencil, eraser)
# 8       0.6          (sharpener, eraser)
# 9       0.6                (pencil, pen)
# 10      0.6          (sharpener, pencil)
# 11      0.6          (book, pen, pencil)
# 12      0.6  (sharpener, eraser, pencil)

# %%
# filter the transaction with confidence >= 0.5
# show the dataframe
result = association_rules(frequent_itemset, metric="confidence", min_threshold=0.5)
result
# Out:
#             antecedents          consequents  ...  leverage  conviction
# 0                (book)                (pen)  ...      0.24         inf
# 1                 (pen)               (book)  ...      0.24         inf
# 2                (book)             (pencil)  ...      0.00         inf
# 3              (pencil)               (book)  ...      0.00         1.0
# 4              (pencil)             (eraser)  ...      0.00         1.0
# 5              (eraser)             (pencil)  ...      0.00         inf
# 6           (sharpener)             (eraser)  ...      0.12         inf
# 7              (eraser)          (sharpener)  ...      0.12         1.6
# 8              (pencil)                (pen)  ...      0.00         1.0
# 9                 (pen)             (pencil)  ...      0.00         inf
# 10          (sharpener)             (pencil)  ...      0.00         inf
# 11             (pencil)          (sharpener)  ...      0.00         1.0
# 12          (book, pen)             (pencil)  ...      0.00         inf
# 13       (book, pencil)                (pen)  ...      0.24         inf
# 14        (pencil, pen)               (book)  ...      0.24         inf
# 15               (book)        (pencil, pen)  ...      0.24         inf
# 16                (pen)       (book, pencil)  ...      0.24         inf
# 17             (pencil)          (book, pen)  ...      0.00         1.0
# 18  (sharpener, eraser)             (pencil)  ...      0.00         inf
# 19  (sharpener, pencil)             (eraser)  ...      0.12         inf
# 20     (pencil, eraser)          (sharpener)  ...      0.12         1.6
# 21          (sharpener)     (pencil, eraser)  ...      0.12         inf
# 22             (eraser)  (sharpener, pencil)  ...      0.12         1.6
# 23             (pencil)  (sharpener, eraser)  ...      0.00         1.0
#
# [24 rows x 9 columns]

# %%
# simplify the dataframe
result_simplify = result[['antecedents', 'consequents', 'support', 'confidence', 'lift']]
result_simplify
# Out:
#             antecedents          consequents  support  confidence      lift
# 0                (book)                (pen)      0.6        1.00  1.666667
# 1                 (pen)               (book)      0.6        1.00  1.666667
# 2                (book)             (pencil)      0.6        1.00  1.000000
# 3              (pencil)               (book)      0.6        0.60  1.000000
# 4              (pencil)             (eraser)      0.8        0.80  1.000000
# 5              (eraser)             (pencil)      0.8        1.00  1.000000
# 6           (sharpener)             (eraser)      0.6        1.00  1.250000
# 7              (eraser)          (sharpener)      0.6        0.75  1.250000
# 8              (pencil)                (pen)      0.6        0.60  1.000000
# 9                 (pen)             (pencil)      0.6        1.00  1.000000
# 10          (sharpener)             (pencil)      0.6        1.00  1.000000
# 11             (pencil)          (sharpener)      0.6        0.60  1.000000
# 12          (book, pen)             (pencil)      0.6        1.00  1.000000
# 13       (book, pencil)                (pen)      0.6        1.00  1.666667
# 14        (pencil, pen)               (book)      0.6        1.00  1.666667
# 15               (book)        (pencil, pen)      0.6        1.00  1.666667
# 16                (pen)       (book, pencil)      0.6        1.00  1.666667
# 17             (pencil)          (book, pen)      0.6        0.60  1.000000
# 18  (sharpener, eraser)             (pencil)      0.6        1.00  1.000000
# 19  (sharpener, pencil)             (eraser)      0.6        1.00  1.250000
# 20     (pencil, eraser)          (sharpener)      0.6        0.75  1.250000
# 21          (sharpener)     (pencil, eraser)      0.6        1.00  1.250000
# 22             (eraser)  (sharpener, pencil)      0.6        0.75  1.250000
# 23             (pencil)  (sharpener, eraser)      0.6        0.60  1.000000
